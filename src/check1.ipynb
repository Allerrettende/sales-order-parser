# %%
line=["name","city","zip","country"]
rline=reversed(line)
print(rline )
for l in reversed(line):
    # print(line[-1])
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 line=["name","city","zip","country"]
# ----> 2 rline=reversed(line)[1]
#       3 print(rline )
#       4 for l in reversed(line):
#       5     # print(line[-1])
#
# TypeError: 'list_reverseiterator' object is not subscriptable

# %%
import re
match = re.search(r'zero*', "zerxxxx")
if match:
    print(match.group())  # 'zer'
    print(match.span())   # (0, 3) - 匹配了前3个字符
