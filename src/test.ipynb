# %%
import pandas as pd

df = pd.read_excel(r"D:\OC\sales order list 20260813.xlsx")
df.shape

# %%
df["sales_order_no"].nunique()
df.groupby("sales_order_no").size()
df.isna().sum()

# %%
item_totals = (
    df.groupby("sales_order_no")["amount"]
      .sum()
)

item_discount_totals= (
    df.groupby("sales_order_no")["discount"]
      .sum()
)
subtotals = (
    df.groupby("sales_order_no")["subtotal_amount"]
      .first()
)

check = pd.DataFrame({
    "item_total": item_totals,
    "item_discount_total":item_discount_totals,
    "subtotal": subtotals
})

check["difference"] = (
    check["subtotal"] - (check["item_total"]+check["item_discount_total"])
)

check

# %%
check[check["difference"].abs() > 0.01]
# Out:
#                 item_total  item_discount_total   subtotal  difference
# sales_order_no
# 2014-864258         3199.0             -1000.00    2340.00       141.0
# 2015-864032         5616.0             -4000.00   11546.00      9930.0
# 2015-864050        44761.0             -1619.50   22380.50    -20761.0
# 2015-864124       128551.0                 0.00  112551.00    -16000.0
# 2015-864154        71910.0                 0.00   74815.20      2905.2
# ...                    ...                  ...        ...         ...
# 2026-864003        44550.0             -3850.00   29205.00    -11495.0
# 2026-864031        37495.0                 0.00   20830.00    -16665.0
# 2026-864042         4306.0              -677.54   33199.46     29571.0
# 2026-864045        37900.0                 0.00   18400.00    -19500.0
# 2026-864078        84011.8                 0.00   42135.90    -41875.9
#
# [250 rows x 4 columns]

# %%
check[check["difference"].abs() > 0.01].head(20)
